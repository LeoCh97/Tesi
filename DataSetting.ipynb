# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoCh97/Tesi/blob/master/DataSetting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
LOG_DIR = './log'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://47eeddaf.ngrok.io

# %%
# !pip install kaggle

# %%
# !mkdir .kaggle

# %%
import json
token = {"username":"leoch97","key":"9458a8195a88568d9eb2b418dd57407c"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !mkdir ~/.kaggle

# %%
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content}
# Out:
# ...
# - path is now set to: {/content}

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d leoch97/logostesi -p /content --unzip

# %%
# !unzip FlickrLogos-32_dataset_v2.zip
# !unzip images.zip
# Out:
# Archive:  FlickrLogos-32_dataset_v2.zip
#    creating: FlickrLogos-v2/
#   inflating: FlickrLogos-v2/all.filenames.txt
#   inflating: FlickrLogos-v2/all.relpaths.txt
#   inflating: FlickrLogos-v2/all.spaces.txt
#   inflating: FlickrLogos-v2/all.txt
#    creating: FlickrLogos-v2/classes/
#    creating: FlickrLogos-v2/classes/jpg/
#    creating: FlickrLogos-v2/classes/jpg/adidas/
#   inflating: FlickrLogos-v2/classes/jpg/adidas/144503924.jpg
#   inflating: FlickrLogos-v2/classes/jpg/adidas/145074777.jpg
#   inflating: FlickrLogos-v2/classes/jpg/adidas/1468736300.jpg
#   inflating: FlickrLogos-v2/classes/jpg/adidas/160469021.jpg
#   inflating: FlickrLogos-v2/classes/jpg/adidas/2266807703.jpg
#   inflating: FlickrLogos-v2/classes/jpg/adidas/2345541572.jpg
#   inflating: FlickrLogos-v2/classes/jpg/adidas/2399696288.jpg
#   inflating: FlickrLogos-v2/classes/jpg/adidas/2403699729.jpg
#   inflating: FlickrLogos-v2/classes/jpg/adidas/2450743885.jpg
# ...

# %%
# !rm *\.zip
# !rm -r __MACOSX
# !mv FlickrLogos-v2/classes/masks/hp FlickrLogos-v2/classes/masks/HP
# !mv FlickrLogos-v2/classes/masks/guiness FlickrLogos-v2/classes/masks/guinness
# !mv FlickrLogos-v2/classes/jpg/guiness FlickrLogos-v2/classes/jpg/guinness
